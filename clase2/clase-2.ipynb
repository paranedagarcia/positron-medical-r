# %% [markdown]
# casos

# %%
imc <- function(peso, altura) {
  peso / (altura/100)^2
}
print(imc(100, 180))
# Out:
# [1] 30.8642

# %%
# funcion artimetica 
# suma de dos numeros
sumados <- function(primero, segundo) {
  primero + segundo
}

sumados(25,5)
# Out:
# [1] 30
